# %%
import pandas as pd

def cargar_y_limpiar_excel(filename):
    # Cargar el archivo Excel y saltar las primeras 7 filas
    df = pd.read_excel(filename, skiprows=7)
    
    # Verificar los nombres de las columnas antes de eliminarlas
    print("Columnas antes de eliminar:", df.columns.tolist())
    
    # Eliminar columnas específicas por nombre si existen en el DataFrame
    columnas_a_eliminar = [
        "Applicants", "Admitted", "Registered", "Lead/Reg", "23/24", "24/25", 
        "Unnamed: 10", "Unnamed: 11", "Unnamed: 12", "Unnamed: 21", "Unnamed: 24", 
        "Unnamed: 25", "Unnamed: 26", "Leads.2", "Unnamed: 31", "Unnamed: 36", 
        "Unnamed: 44", "Unnamed: 45", "Unnamed: 46", "Unnamed: 47", "Unnamed: 48", 
        "Unnamed: 49", "Unnamed: 50", "Unnamed: 51", "Unnamed: 52", "Unnamed: 38", 
        "Unnamed: 40", "Unnamed: 42"
    ]
    
    # Eliminar las columnas de la lista si existen en el DataFrame
    columnas_a_eliminar_presentes = [col for col in columnas_a_eliminar if col in df.columns]
    df = df.drop(columns=columnas_a_eliminar_presentes, errors='ignore')
    
    # Mostrar las columnas después de la eliminación
    print("Columnas después de eliminar:", df.columns.tolist())
    
    # Mantener columnas que contienen "Unnamed" o "Leads"
    columnas_salvar = [col for col in df.columns if "Unnamed" in str(col) or "Leads" in str(col)]
    df = df[columnas_salvar]
    
    return df

# Crear un DataFrame por cada archivo
df_week_1_04_01_24 = cargar_y_limpiar_excel("excel_prueba_1.xlsx")
df_week_2_11_01_24 = cargar_y_limpiar_excel("excel_prueba_2.xlsx")
df_week_3_18_01_24 = cargar_y_limpiar_excel("excel_prueba_3.xlsx")
df_week_4_25_01_24 = cargar_y_limpiar_excel("excel_prueba_4.xlsx")
df_week_5_01_02_24 = cargar_y_limpiar_excel("excel_prueba_5.xlsx")
df_week_6_08_02_24 = cargar_y_limpiar_excel("excel_prueba_6.xlsx")
df_week_7_15_02_24 = cargar_y_limpiar_excel("excel_prueba_7.xlsx")
df_week_8_22_02_24 = cargar_y_limpiar_excel("excel_prueba_8.xlsx")
df_week_9_29_02_24 = cargar_y_limpiar_excel("excel_prueba_9.xlsx")
df_week_10_07_03_24 = cargar_y_limpiar_excel("excel_prueba_10.xlsx")
df_week_11_14_03_24 = cargar_y_limpiar_excel("excel_prueba_11.xlsx")
df_week_12_21_03_24 = cargar_y_limpiar_excel("excel_prueba_12.xlsx")
df_week_13_28_03_24 = cargar_y_limpiar_excel("excel_prueba_13.xlsx")
df_week_14_04_04_24 = cargar_y_limpiar_excel("excel_prueba_14.xlsx")
df_week_15_11_04_24 = cargar_y_limpiar_excel("excel_prueba_15.xlsx")
df_week_16_18_04_24 = cargar_y_limpiar_excel("excel_prueba_16.xlsx")
df_week_17_25_04_24 = cargar_y_limpiar_excel("excel_prueba_17.xlsx")
df_week_18_03_05_24 = cargar_y_limpiar_excel("excel_prueba_18.xlsx")
df_week_19_09_05_24 = cargar_y_limpiar_excel("excel_prueba_19.xlsx")
df_week_20_17_05_24 = cargar_y_limpiar_excel("excel_prueba_20.xlsx")
df_week_21_24_05_24 = cargar_y_limpiar_excel("excel_prueba_21.xlsx")
df_week_22_30_05_24 = cargar_y_limpiar_excel("excel_prueba_22.xlsx")
df_week_23_06_06_24 = cargar_y_limpiar_excel("excel_prueba_23.xlsx")
df_week_24_13_06_24 = cargar_y_limpiar_excel("excel_prueba_24.xlsx")
df_week_25_21_06_24 = cargar_y_limpiar_excel("excel_prueba_25.xlsx")
df_week_26_27_06_24 = cargar_y_limpiar_excel("excel_prueba_26.xlsx")
df_week_27_04_07_24 = cargar_y_limpiar_excel("excel_prueba_27.xlsx")
df_week_28_11_07_24 = cargar_y_limpiar_excel("excel_prueba_28.xlsx")
df_week_29_18_07_24 = cargar_y_limpiar_excel("excel_prueba_29.xlsx")
df_week_30_26_07_24 = cargar_y_limpiar_excel("excel_prueba_30.xlsx")
df_week_31_02_08_24 = cargar_y_limpiar_excel("excel_prueba_31.xlsx")
df_week_32_07_08_24 = cargar_y_limpiar_excel("excel_prueba_32.xlsx")
df_week_33_15_08_24 = cargar_y_limpiar_excel("excel_prueba_33.xlsx")
df_week_34_22_08_24 = cargar_y_limpiar_excel("excel_prueba_34.xlsx")
df_week_35_29_08_24 = cargar_y_limpiar_excel("excel_prueba_35.xlsx")
df_week_36_05_09_24 = cargar_y_limpiar_excel("excel_prueba_36.xlsx")
df_week_37_12_09_24 = cargar_y_limpiar_excel("excel_prueba_37.xlsx")
df_week_38_19_09_24 = cargar_y_limpiar_excel("excel_prueba_38.xlsx")
df_week_39_26_09_24 = cargar_y_limpiar_excel("excel_prueba_39.xlsx")
df_week_40_03_10_24 = cargar_y_limpiar_excel("excel_prueba_40.xlsx")
df_week_41_10_10_24 = cargar_y_limpiar_excel("excel_prueba_41.xlsx")
df_week_42_17_10_24 = cargar_y_limpiar_excel("excel_prueba_42.xlsx")
df_week_43_24_10_24 = cargar_y_limpiar_excel("excel_prueba_43.xlsx")
df_week_44_31_10_24 = cargar_y_limpiar_excel("excel_prueba_44.xlsx")
df_week_45_08_11_24 = cargar_y_limpiar_excel("excel_prueba_45.xlsx")
df_week_45_10_11_23 = cargar_y_limpiar_excel("excel_prueba_46.xlsx")
df_week_46_15_11_24 = cargar_y_limpiar_excel("excel_prueba_47.xlsx")
df_week_46_16_11_23 = cargar_y_limpiar_excel("excel_prueba_48.xlsx")
df_week_47_22_11_24 = cargar_y_limpiar_excel("excel_prueba_49.xlsx")
df_week_48_30_11_23 = cargar_y_limpiar_excel("excel_prueba_50.xlsx")
df_week_49_07_12_23 = cargar_y_limpiar_excel("excel_prueba_51.xlsx")
df_week_50_14_12_23 = cargar_y_limpiar_excel("excel_prueba_52.xlsx")
df_week_51_21_12_23 = cargar_y_limpiar_excel("excel_prueba_53.xlsx")
df_week_52_28_12_23 = cargar_y_limpiar_excel("excel_prueba_54.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 34
#      31     return df
#      33 # Crear un DataFrame por cada archivo
# ---> 34 df_week_1_04_01_24 = cargar_y_limpiar_excel("excel_prueba_1.xlsx")
#      35 df_week_2_11_01_24 = cargar_y_limpiar_excel("excel_prueba_2.xlsx")
#      36 df_week_3_18_01_24 = cargar_y_limpiar_excel("excel_prueba_3.xlsx")
#
# Cell In[1], line 5, in cargar_y_limpiar_excel(filename)
#       3 def cargar_y_limpiar_excel(filename):
#       4     # Cargar el archivo Excel y saltar las primeras 7 filas
# ----> 5     df = pd.read_excel(filename, skiprows=7)
#       7     # Verificar los nombres de las columnas antes de eliminarlas
#       8     print("Columnas antes de eliminar:", df.columns.tolist())
#
# ...

# %%
# Lista de todos los DataFrames creados
dataframes = [
    df_week_1_04_01_24, df_week_2_11_01_24, df_week_3_18_01_24, df_week_4_25_01_24,
    df_week_5_01_02_24, df_week_6_08_02_24, df_week_7_15_02_24, df_week_8_22_02_24,
    df_week_9_29_02_24, df_week_10_07_03_24, df_week_11_14_03_24, df_week_12_21_03_24,
    df_week_13_28_03_24, df_week_14_04_04_24, df_week_15_11_04_24, df_week_16_18_04_24,
    df_week_17_25_04_24, df_week_18_03_05_24, df_week_19_09_05_24, df_week_20_17_05_24,
    df_week_21_24_05_24, df_week_22_30_05_24, df_week_23_06_06_24, df_week_24_13_06_24,
    df_week_25_21_06_24, df_week_26_27_06_24, df_week_27_04_07_24, df_week_28_11_07_24,
    df_week_29_18_07_24, df_week_30_26_07_24, df_week_31_02_08_24, df_week_32_07_08_24,
    df_week_33_15_08_24, df_week_34_22_08_24, df_week_35_29_08_24, df_week_36_05_09_24,
    df_week_37_12_09_24, df_week_38_19_09_24, df_week_39_26_09_24, df_week_40_03_10_24,
    df_week_41_10_10_24, df_week_42_17_10_24, df_week_43_24_10_24, df_week_44_31_10_24,
    df_week_45_08_11_24, df_week_45_10_11_23, df_week_46_15_11_24, df_week_46_16_11_23, df_week_47_22_11_24, 
    df_week_48_30_11_23, df_week_49_07_12_23, df_week_50_14_12_23, df_week_51_21_12_23, df_week_52_28_12_23
]

# Función para renombrar las columnas específicas
def renombrar_columnas(df):
    # Diccionario de mapeo para cambiar los nombres de las columnas
    columnas_renombrar = {
        "Unnamed: 1": "product",
        "Unnamed: 4": "ly_applicants", 
        "Unnamed: 6": "ly_admitted", 
        "Unnamed: 8": "ly_registered", 
        "Unnamed: 15": "applicants", 
        "Unnamed: 17": "admitted", 
        "Unnamed: 19": "registered"
    }

# Renombrar columnas con nombres únicos, si hay duplicados de 'Leads*'
    df = df.rename(columns=columnas_renombrar)

    # Buscar las columnas que contienen 'Leads*' y renombrarlas por índice
    leads_columns = [col for col in df.columns if 'Leads*' in col]

    # Renombrar las columnas 'Leads*' si existen
    if len(leads_columns) > 0:
        df = df.rename(columns={leads_columns[0]: "ly_leads"})  # Primer 'Leads*'
    if len(leads_columns) > 1:
        df = df.rename(columns={leads_columns[1]: "leads"})  # Segundo 'Leads*'

    return df

# Función para agregar la columna 'region'
def agregar_region(df):
    # Crear la columna 'region' inicialmente con valores vacíos
    df.insert(0, 'region', '')  # Insertar la columna 'region' en la primera posición
    
    # Asignar los valores 'nacional', 'internacional' y 'global' según las filas
    df.loc[0:4, 'region'] = 'nacional'  # Filas 0 a 4 -> nacional
    df.loc[6:11, 'region'] = 'internacional'  # Filas 6 a 9 -> internacional
    df.loc[12:18, 'region'] = 'global'  # Filas 12 a 15 -> global
    
    # Eliminar las filas 5, 10 y 11
    df = df.drop([11, 10, 5, 4], errors='ignore')  # errors='ignore' para evitar error si algún índice no existe
    return df

# Procesar y renombrar todos los DataFrames
for i in range(len(dataframes)):
    # Eliminar filas 1 y 2 y la columna 1
    dataframes[i] = dataframes[i].iloc[2:, 1:].reset_index(drop=True)
    # Renombrar columnas
    dataframes[i] = renombrar_columnas(dataframes[i])
    # Añadir columna región
    dataframes[i] = agregar_region(dataframes[i])

# Reasignar los DataFrames si es necesario
(df_week_1_04_01_24, df_week_2_11_01_24, df_week_3_18_01_24, df_week_4_25_01_24,
    df_week_5_01_02_24, df_week_6_08_02_24, df_week_7_15_02_24, df_week_8_22_02_24,
    df_week_9_29_02_24, df_week_10_07_03_24, df_week_11_14_03_24, df_week_12_21_03_24,
    df_week_13_28_03_24, df_week_14_04_04_24, df_week_15_11_04_24, df_week_16_18_04_24,
    df_week_17_25_04_24, df_week_18_03_05_24, df_week_19_09_05_24, df_week_20_17_05_24,
    df_week_21_24_05_24, df_week_22_30_05_24, df_week_23_06_06_24, df_week_24_13_06_24,
    df_week_25_21_06_24, df_week_26_27_06_24, df_week_27_04_07_24, df_week_28_11_07_24,
    df_week_29_18_07_24, df_week_30_26_07_24, df_week_31_02_08_24, df_week_32_07_08_24,
    df_week_33_15_08_24, df_week_34_22_08_24, df_week_35_29_08_24, df_week_36_05_09_24,
    df_week_37_12_09_24, df_week_38_19_09_24, df_week_39_26_09_24, df_week_40_03_10_24,
    df_week_41_10_10_24, df_week_42_17_10_24, df_week_43_24_10_24, df_week_44_31_10_24,
    df_week_45_08_11_24, df_week_45_10_11_23, df_week_46_15_11_24, df_week_46_16_11_23, df_week_47_22_11_24, 
    df_week_48_30_11_23, df_week_49_07_12_23, df_week_50_14_12_23, df_week_51_21_12_23, df_week_52_28_12_23) = dataframes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Lista de todos los DataFrames creados
#       2 dataframes = [
# ----> 3     df_week_1_04_01_24, df_week_2_11_01_24, df_week_3_18_01_24, df_week_4_25_01_24,
#       4     df_week_5_01_02_24, df_week_6_08_02_24, df_week_7_15_02_24, df_week_8_22_02_24,
#       5     df_week_9_29_02_24, df_week_10_07_03_24, df_week_11_14_03_24, df_week_12_21_03_24,
#       6     df_week_13_28_03_24, df_week_14_04_04_24, df_week_15_11_04_24, df_week_16_18_04_24,
#       7     df_week_17_25_04_24, df_week_18_03_05_24, df_week_19_09_05_24, df_week_20_17_05_24,
#       8     df_week_21_24_05_24, df_week_22_30_05_24, df_week_23_06_06_24, df_week_24_13_06_24,
#       9     df_week_25_21_06_24, df_week_26_27_06_24, df_week_27_04_07_24, df_week_28_11_07_24,
# ...

# %%
# Ajustar la configuración para mostrar todas las filas y columnas
pd.set_option('display.max_rows', None)  # No limitar el número de filas mostradas
pd.set_option('display.max_columns', None)  # No limitar el número de columnas mostradas
pd.set_option('display.width', None)  # No limitar el ancho de la tabla
pd.set_option('display.max_colwidth', None)  # No limitar el ancho de las columnas

df_week_21_24_05_24
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 pd.set_option('display.width', None)  # No limitar el ancho de la tabla
#       5 pd.set_option('display.max_colwidth', None)  # No limitar el ancho de las columnas
# ----> 7 df_week_21_24_05_24
#
# NameError: name 'df_week_21_24_05_24' is not defined

# %%
#Creación de columna semana y columna fecha, tomando los valores del nombre de cada 

dataframes = {
    'df_week_1_04_01_24': df_week_1_04_01_24,
    'df_week_2_11_01_24': df_week_2_11_01_24,
    'df_week_3_18_01_24': df_week_3_18_01_24,
    'df_week_4_25_01_24': df_week_4_25_01_24,
    'df_week_5_01_02_24': df_week_5_01_02_24,
    'df_week_6_08_02_24': df_week_6_08_02_24,
    'df_week_7_15_02_24': df_week_7_15_02_24,
    'df_week_8_22_02_24': df_week_8_22_02_24,
    'df_week_9_29_02_24': df_week_9_29_02_24,
    'df_week_10_07_03_24': df_week_10_07_03_24,
    'df_week_11_14_03_24': df_week_11_14_03_24,
    'df_week_12_21_03_24': df_week_12_21_03_24,
    'df_week_13_28_03_24': df_week_13_28_03_24,
    'df_week_14_04_04_24': df_week_14_04_04_24,
    'df_week_15_11_04_24': df_week_15_11_04_24,
    'df_week_16_18_04_24': df_week_16_18_04_24,
    'df_week_17_25_04_24': df_week_17_25_04_24,
    'df_week_18_03_05_24': df_week_18_03_05_24,
    'df_week_19_09_05_24': df_week_19_09_05_24,
    'df_week_20_17_05_24': df_week_20_17_05_24,
    'df_week_21_24_05_24': df_week_21_24_05_24,
    'df_week_22_30_05_24': df_week_22_30_05_24,
    'df_week_23_06_06_24': df_week_23_06_06_24,
    'df_week_24_13_06_24': df_week_24_13_06_24,
    'df_week_25_21_06_24': df_week_25_21_06_24,
    'df_week_26_27_06_24': df_week_26_27_06_24,
    'df_week_27_04_07_24': df_week_27_04_07_24,
    'df_week_28_11_07_24': df_week_28_11_07_24,
    'df_week_29_18_07_24': df_week_29_18_07_24,
    'df_week_30_26_07_24': df_week_30_26_07_24,
    'df_week_31_02_08_24': df_week_31_02_08_24,
    'df_week_32_07_08_24': df_week_32_07_08_24,
    'df_week_33_15_08_24': df_week_33_15_08_24,
    'df_week_34_22_08_24': df_week_34_22_08_24,
    'df_week_35_29_08_24': df_week_35_29_08_24,
    'df_week_36_05_09_24': df_week_36_05_09_24,
    'df_week_37_12_09_24': df_week_37_12_09_24,
    'df_week_38_19_09_24': df_week_38_19_09_24,
    'df_week_39_26_09_24': df_week_39_26_09_24,
    'df_week_40_03_10_24': df_week_40_03_10_24,
    'df_week_41_10_10_24': df_week_41_10_10_24,
    'df_week_42_17_10_24': df_week_42_17_10_24,
    'df_week_43_24_10_24': df_week_43_24_10_24,
    'df_week_44_31_10_24': df_week_44_31_10_24,
    'df_week_45_10_11_23': df_week_45_10_11_23,
    'df_week_45_08_11_24': df_week_45_08_11_24,
    'df_week_46_16_11_23': df_week_46_16_11_23,
    'df_week_46_15_11_24': df_week_46_15_11_24,
    'df_week_47_22_11_24': df_week_47_22_11_24,
    'df_week_48_30_11_23': df_week_48_30_11_23,
    'df_week_49_07_12_23': df_week_49_07_12_23,
    'df_week_50_14_12_23': df_week_50_14_12_23,
    'df_week_51_21_12_23': df_week_51_21_12_23,
    'df_week_52_28_12_23': df_week_52_28_12_23
}

# Bucle para añadir las columnas
for name, df in dataframes.items():
    # Extrae el número de semana del nombre del DataFrame
    week_number = int(name.split('_')[2])
    
    # Extrae la fecha del nombre del DataFrame
    date_str = name.split('_')[-3:]
    date_str = '_'.join(date_str)  # Forma: '31_10_24'
    
    # Convierte la fecha en formato 'dd_mm_yy' a un objeto datetime
    date = pd.to_datetime(date_str, format='%d_%m_%y')
    
    # Añade las columnas al DataFrame
    df['Curso'] = "24-25"  # Cambia si necesitas otro valor
    df['Semana'] = week_number
    df['Fecha'] = date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 #Creación de columna semana y columna fecha, tomando los valores del nombre de cada
#       3 dataframes = {
# ----> 4     'df_week_1_04_01_24': df_week_1_04_01_24,
#       5     'df_week_2_11_01_24': df_week_2_11_01_24,
#       6     'df_week_3_18_01_24': df_week_3_18_01_24,
#       7     'df_week_4_25_01_24': df_week_4_25_01_24,
#       8     'df_week_5_01_02_24': df_week_5_01_02_24,
#       9     'df_week_6_08_02_24': df_week_6_08_02_24,
#      10     'df_week_7_15_02_24': df_week_7_15_02_24,
#      11     'df_week_8_22_02_24': df_week_8_22_02_24,
#      12     'df_week_9_29_02_24': df_week_9_29_02_24,
#      13     'df_week_10_07_03_24': df_week_10_07_03_24,
#      14     'df_week_11_14_03_24': df_week_11_14_03_24,
#      15     'df_week_12_21_03_24': df_week_12_21_03_24,
# ...

# %%
#Concatenar dataframes para hacer tabla única

dataframes = {
    'df_week_1_04_01_24': df_week_1_04_01_24,
    'df_week_2_11_01_24': df_week_2_11_01_24,
    'df_week_3_18_01_24': df_week_3_18_01_24,
    'df_week_4_25_01_24': df_week_4_25_01_24,
    'df_week_5_01_02_24': df_week_5_01_02_24,
    'df_week_6_08_02_24': df_week_6_08_02_24,
    'df_week_7_15_02_24': df_week_7_15_02_24,
    'df_week_8_22_02_24': df_week_8_22_02_24,
    'df_week_9_29_02_24': df_week_9_29_02_24,
    'df_week_10_07_03_24': df_week_10_07_03_24,
    'df_week_11_14_03_24': df_week_11_14_03_24,
    'df_week_12_21_03_24': df_week_12_21_03_24,
    'df_week_13_28_03_24': df_week_13_28_03_24,
    'df_week_14_04_04_24': df_week_14_04_04_24,
    'df_week_15_11_04_24': df_week_15_11_04_24,
    'df_week_16_18_04_24': df_week_16_18_04_24,
    'df_week_17_25_04_24': df_week_17_25_04_24,
    'df_week_18_03_05_24': df_week_18_03_05_24,
    'df_week_19_09_05_24': df_week_19_09_05_24,
    'df_week_20_17_05_24': df_week_20_17_05_24,
    'df_week_21_24_05_24': df_week_21_24_05_24,
    'df_week_22_30_05_24': df_week_22_30_05_24,
    'df_week_23_06_06_24': df_week_23_06_06_24,
    'df_week_24_13_06_24': df_week_24_13_06_24,
    'df_week_25_21_06_24': df_week_25_21_06_24,
    'df_week_26_27_06_24': df_week_26_27_06_24,
    'df_week_27_04_07_24': df_week_27_04_07_24,
    'df_week_28_11_07_24': df_week_28_11_07_24,
    'df_week_29_18_07_24': df_week_29_18_07_24,
    'df_week_30_26_07_24': df_week_30_26_07_24,
    'df_week_31_02_08_24': df_week_31_02_08_24,
    'df_week_32_07_08_24': df_week_32_07_08_24,
    'df_week_33_15_08_24': df_week_33_15_08_24,
    'df_week_34_22_08_24': df_week_34_22_08_24,
    'df_week_35_29_08_24': df_week_35_29_08_24,
    'df_week_36_05_09_24': df_week_36_05_09_24,
    'df_week_37_12_09_24': df_week_37_12_09_24,
    'df_week_38_19_09_24': df_week_38_19_09_24,
    'df_week_39_26_09_24': df_week_39_26_09_24,
    'df_week_40_03_10_24': df_week_40_03_10_24,
    'df_week_41_10_10_24': df_week_41_10_10_24,
    'df_week_42_17_10_24': df_week_42_17_10_24,
    'df_week_43_24_10_24': df_week_43_24_10_24,
    'df_week_44_31_10_24': df_week_44_31_10_24,
    'df_week_45_10_11_23': df_week_45_10_11_23,
    'df_week_45_08_11_24': df_week_45_08_11_24,
    'df_week_46_16_11_23': df_week_46_16_11_23,
    'df_week_46_15_11_24': df_week_46_15_11_24,
    'df_week_47_22_11_24': df_week_47_22_11_24,
    'df_week_48_30_11_23': df_week_48_30_11_23,
    'df_week_49_07_12_23': df_week_49_07_12_23,
    'df_week_50_14_12_23': df_week_50_14_12_23,
    'df_week_51_21_12_23': df_week_51_21_12_23,
    'df_week_52_28_12_23': df_week_52_28_12_23
}

df_concatenado = pd.concat(dataframes.values(), ignore_index=True)

df_concatenado
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 #Concatenar dataframes para hacer tabla única
#       3 dataframes = {
# ----> 4     'df_week_1_04_01_24': df_week_1_04_01_24,
#       5     'df_week_2_11_01_24': df_week_2_11_01_24,
#       6     'df_week_3_18_01_24': df_week_3_18_01_24,
#       7     'df_week_4_25_01_24': df_week_4_25_01_24,
#       8     'df_week_5_01_02_24': df_week_5_01_02_24,
#       9     'df_week_6_08_02_24': df_week_6_08_02_24,
#      10     'df_week_7_15_02_24': df_week_7_15_02_24,
#      11     'df_week_8_22_02_24': df_week_8_22_02_24,
#      12     'df_week_9_29_02_24': df_week_9_29_02_24,
#      13     'df_week_10_07_03_24': df_week_10_07_03_24,
#      14     'df_week_11_14_03_24': df_week_11_14_03_24,
#      15     'df_week_12_21_03_24': df_week_12_21_03_24,
#      16     'df_week_13_28_03_24': df_week_13_28_03_24,
# ...

# %%
#Bajar el excel final concatenado
df_concatenado.to_csv("reporte_concatenado.csv", index=False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Bajar el excel final concatenado
# ----> 2 df_concatenado.to_csv("reporte_concatenado.csv", index=False, encoding='utf-8-sig')
#
# NameError: name 'df_concatenado' is not defined
